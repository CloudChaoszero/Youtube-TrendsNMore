# %% [markdown]
# ![Old Youtube logo](http://moziru.com/images/youtube-clipart-youtube-logo-4.png)

# %% [markdown]
# # Video Trends and More
#
# by Raul Maldonado

# %% [markdown]
# ## 1.0 Introduction
#
# Welcome! We explore some of the interesting simple numbers of trending Youtube videos from **mid-November 2017 until January 2018.** In total, we have an estimated 50,000 records to evaluate--So, let's get started! 😊
#
# ### 1.1 Importing Modules and Data
#
# We initially import our information and tools for this analysis. There a couple of comments to this initial process:
#
# 1. Data was provided by Kaggle User Mitchell J. in several files, but I went through the data-cleaning process in [this DataCleaning folder](../DataInspection).
#
# 2. I created a quick Descriptive Statistic function for this particular dataset. You can find this .py file in the [Resources folder](../Resources)

# %%
import sys
sys.path.insert(0,"../Resources/Modules")

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime 

#Personal module for quick Descriptive Stat Viz
import visual_descriptiveStats as vds

# %%
ytVid_df = pd.read_csv("../Data/youtubeVid_main.csv",sep = ",")

#format the trend date from string format of mm/dd/yy to date 
#format mm-dd-yy, for correct datatype assignment

ytVid_df["trending_date"] = pd.to_datetime(ytVid_df["trending_date"] \
                                           , format = "%m/%d/%Y")

# %%
youtube_df =ytVid_df.groupby(["video_id","Country"], group_keys=False, as_index=False \
                           ).apply(lambda x: x.loc[x.trending_date.idxmax()])

# %% [markdown]
# ## 1.2 Preliminary Thoughts

# %% [markdown]
# ### 1.2.1 Question # 1
#
# What are the top 10 trending
#
# 1. **Youtube videos**
# 2. **Categories**
# 3. **Youtubers**
#
# ### 1.2.2 Question # 2
#
# After identifying what countries do these Video and youtuber fans mainly come from?
#
# Also, do these youtube videos have more hate or liking for the video and youtuber content?

# %% [markdown]
# ## 2.0 Analysis
#
# ### 2.1 Total Views Per Day
#
# The following visualization identifies the total views per day between 11/2017-01/2018.

# %%
ytDf_ttrendDate = youtube_df["trending_date"]
ytDf_views = youtube_df["views"]

order = np.argsort(ytDf_ttrendDate )
x_trendDate = np.array(ytDf_ttrendDate)[order]
y_views = np.array(ytDf_views )[order]

# %%
print("During the period of October 2017 until January 2018, \
      we had a total of %d views. In the following distribution, \
      we can see the total views per day" %  (youtube_df["views"].sum()))

plt.figure(1)
plt.subplot(211)


plt.title("Total Views Per day (11/2017 to 1/2018)")
plt.xticks(rotation = "vertical")
plt.xlabel("Time")
plt.ylabel("Views")
plt.plot(x)trendDate,y_views)
plt.show()
# Out:
# During the period of October 2017 until January 2018, we had a total of 58064886664 views. In the following distribution, we can see the total views per day

# %% [markdown]
# We observe a major increase of Youtube views from beginning of December 2017 until its end.

# %% [markdown]
# ### 2.1 Top 10 from Channels, Videos, and Categories
#
# We now identify the top 10 viewed trending channels, videos, and categories from November 2017-January 2018.
#
# From identifying these ranks for each feature, we identify the countries that  took the most interest for such feature. (E.g. For Youtube Highlights in several countries, we see that some country China viewed it more than any other country)
#
# We'll proceed through these rankings by Youtube
#
# 1. Users (Channel Titles)
#
# 2. Videos (Titles)
#
# 3. Categories

# %%
#Convert Pivot table to DataFrame
def pivotTab_toDF(dataset, value, indices, aggregFunct):
    #Pivot table
    dFrame = dataset.pivot_table(values = value, index= [ \
        indices], aggfunc = aggregFunct).sort_values(by = value, ascending = False)
    
    #Convert Pivot Table to a Dataframe
    dFrame = pd.DataFrame(dFrame.to_records())
    
    #Labeling for aggregation from pivot table
    dFrame.columns = [indices,"total_%s" % value]
    
    return(dFrame)

# %% [markdown]
# #### 2.1.1 Top 10 Users (Channel Titles)

# %%
topUsers_df = pivotTab_toDF(dataset = youtube_df, value="views" \
                            , indices = "channel_title", aggregFunct = np.sum)[:10]
print("Top 10 Youtube Channels:\n")
topUsers_df
# Out:
# Top 10 Youtube Channels:
#           channel_title  total_views
# 0     YouTube Spotlight    674196442
# 1            Ed Sheeran    558250009
# 2         LuisFonsiVEVO    387989509
# 3  Marvel Entertainment    380297875
# 4            EminemVEVO    263301085
# 5        GEazyMusicVEVO    224006918
# 6       5-Minute Crafts    200769312
# 7      jypentertainment    193145941
# 8               ibighit    190216895
# 9    Universal Pictures    186855788

# %% [markdown]
# #### 2.1.2 Top 10 Youtube Videos

# %%
topVideo_df = pivotTab_toDF(dataset = youtube_df, value="views", \
                            indices = "title", aggregFunct = np.sum)[:10]
print("Top 10 Youtube Videos:\n")
topVideo_df
# Out:
# Top 10 Youtube Videos:
#                                                title  total_views
# 0  YouTube Rewind: The Shape of 2017 | #YouTubeRe...    671891614
# 1          Luis Fonsi, Demi Lovato - Échame La Culpa    387989509
# 2  Marvel Studios' Avengers: Infinity War Officia...    362897110
# 3        Ed Sheeran - Perfect (Official Music Video)    288157980
# 4  Ed Sheeran - Perfect Duet (with Beyoncé) [Offi...    184327990
# 5                             TWICE Heart Shaker M/V    167131962
# 6  BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...    163806412
# 7  G-Eazy - No Limit REMIX ft. A$AP Rocky, Cardi ...    150460228
# 8  Jurassic World: Fallen Kingdom - Official Trai...    149468770
# 9               Post Malone - rockstar ft. 21 Savage    140265611

# %% [markdown]
# #### 2.1.3 Top 5 Categories

# %%
topCat_df = pivotTab_toDF(dataset = youtube_df, value="views", \
                          indices = "category_name", aggregFunct = np.sum)[:5]
print("Top 5 Youtube Categories:\n")
topUsers_df
# Out:
# Top 5 Youtube Categories:
#           channel_title  total_views
# 0     YouTube Spotlight    674196442
# 1            Ed Sheeran    558250009
# 2         LuisFonsiVEVO    387989509
# 3  Marvel Entertainment    380297875
# 4            EminemVEVO    263301085
# 5        GEazyMusicVEVO    224006918
# 6       5-Minute Crafts    200769312
# 7      jypentertainment    193145941
# 8               ibighit    190216895
# 9    Universal Pictures    186855788

# %% [markdown]
# ### 2.2  Which Countries Populate the Top Category, Youtuber, or Youtube Video, Views?

# %%
#Obtaining the list of Top features
channel_namesC = list(topUsers_df["channel_title"])
title_namesC = list(topVideo_df["title"])
category_namesC = list(topCat_df["category_name"])

# %% [markdown]
# #### 2.2.1 Countries that Dominate the Top 10 Users (Channel Titles)

# %%
#Youtube videos by country
evalu  = youtube_df[youtube_df["channel_title"].isin(channel_namesC)]

# %%
evalu.loc[evalu.groupby(["channel_title"])["views"].idxmax()]
# Out:
#                         video_id trending_date  \
# video_id    Country
# _9YMpuLDnwo USA      _9YMpuLDnwo    2017-12-11
# 2Vv-BfVoq4g GB       2Vv-BfVoq4g    2017-11-27
# n1WpP7iowLc GB       n1WpP7iowLc    2017-11-27
# l_lblj8Cq0o GB       l_lblj8Cq0o    2018-01-05
# TyHvyGVs42U GB       TyHvyGVs42U    2017-12-01
# 6ZfuNTqbHE8 GB       6ZfuNTqbHE8    2017-12-14
# vn9mMeWcgoM GB       vn9mMeWcgoM    2017-12-19
# FlsCjmMhFmw GB       FlsCjmMhFmw    2017-12-24
# kTlv5_Bs8aw GB       kTlv5_Bs8aw    2017-12-07
# rRzxEiBLQCA GB       rRzxEiBLQCA    2017-12-24
#
#                                                                  title  \
# video_id    Country
# _9YMpuLDnwo USA       42 HOLY GRAIL HACKS THAT WILL SAVE YOU A FORTUNE
# 2Vv-BfVoq4g GB             Ed Sheeran - Perfect (Official Music Video)
# n1WpP7iowLc GB              Eminem - Walk On Water (Audio) ft. Beyoncé
# l_lblj8Cq0o GB       G-Eazy - No Limit REMIX ft. A$AP Rocky, Cardi ...
# TyHvyGVs42U GB               Luis Fonsi, Demi Lovato - Échame La Culpa
# 6ZfuNTqbHE8 GB       Marvel Studios' Avengers: Infinity War Officia...
# vn9mMeWcgoM GB       Jurassic World: Fallen Kingdom - Official Trai...
# FlsCjmMhFmw GB       YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# kTlv5_Bs8aw GB       BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# rRzxEiBLQCA GB                                  TWICE Heart Shaker M/V
#
#                             channel_title  category_id   category_name  \
# video_id    Country
# _9YMpuLDnwo USA           5-Minute Crafts           26   Howto & Style
# 2Vv-BfVoq4g GB                 Ed Sheeran           10           Music
# n1WpP7iowLc GB                 EminemVEVO           10           Music
# l_lblj8Cq0o GB             GEazyMusicVEVO           10           Music
# TyHvyGVs42U GB              LuisFonsiVEVO           10           Music
# 6ZfuNTqbHE8 GB       Marvel Entertainment           24   Entertainment
# vn9mMeWcgoM GB         Universal Pictures           24   Entertainment
# FlsCjmMhFmw GB          YouTube Spotlight           24   Entertainment
# kTlv5_Bs8aw GB                    ibighit           10           Music
# rRzxEiBLQCA GB           jypentertainment           10           Music
#
#                                  publish_time      views    likes  dislikes  \
# video_id    Country
# _9YMpuLDnwo USA      2017-12-03T08:30:00.000Z   54155921   378111     66632
# 2Vv-BfVoq4g GB       2017-11-09T11:04:14.000Z  138578860  2584773     49428
# n1WpP7iowLc GB       2017-11-10T17:00:03.000Z   39235314  1044324     63815
# l_lblj8Cq0o GB       2017-12-19T20:00:05.000Z   56253155   805351     49423
# TyHvyGVs42U GB       2017-11-17T05:00:01.000Z  143408235  2686169    137938
# 6ZfuNTqbHE8 GB       2017-11-29T13:26:24.000Z  100672931  2701353     56313
# vn9mMeWcgoM GB       2017-12-08T01:44:25.000Z   41612497   566948     28954
# FlsCjmMhFmw GB       2017-12-06T17:58:51.000Z  169884583  3312868   1753274
# kTlv5_Bs8aw GB       2017-11-24T09:00:02.000Z   54083634  2960250     57944
# rRzxEiBLQCA GB       2017-12-11T08:59:59.000Z   55754734  1052809    103994
#
#                      comment_count  comments_disabled  ratings_disabled  \
# video_id    Country
# _9YMpuLDnwo USA              24679              False             False
# 2Vv-BfVoq4g GB              113639              False             False
# n1WpP7iowLc GB              137383              False             False
# l_lblj8Cq0o GB               46178              False             False
# TyHvyGVs42U GB              144217              False             False
# 6ZfuNTqbHE8 GB              368739              False             False
# vn9mMeWcgoM GB               68309              False             False
# FlsCjmMhFmw GB              845233              False             False
# kTlv5_Bs8aw GB              556154              False             False
# rRzxEiBLQCA GB              169779              False             False
#
#                      video_error_or_removed Country
# video_id    Country
# _9YMpuLDnwo USA                       False     USA
# 2Vv-BfVoq4g GB                        False      GB
# n1WpP7iowLc GB                        False      GB
# l_lblj8Cq0o GB                        False      GB
# TyHvyGVs42U GB                        False      GB
# 6ZfuNTqbHE8 GB                        False      GB
# vn9mMeWcgoM GB                        False      GB
# FlsCjmMhFmw GB                        False      GB
# kTlv5_Bs8aw GB                        False      GB
# rRzxEiBLQCA GB                        False      GB

# %% [markdown]
# #### 2.2.2 Countries that Dominate Top 10 Users (Channel Titles)

# %%
eval2 = youtube_df[youtube_df["title"].isin(title_namesC)]
eval2.loc[eval2.groupby(["title"])["views"].idxmax()]
# Out:
#                         video_id trending_date  \
# video_id    Country
# kTlv5_Bs8aw GB       kTlv5_Bs8aw    2017-12-07
# 2Vv-BfVoq4g GB       2Vv-BfVoq4g    2017-11-27
# 817P8W8-mGE GB       817P8W8-mGE    2017-12-15
# l_lblj8Cq0o GB       l_lblj8Cq0o    2018-01-05
# vn9mMeWcgoM GB       vn9mMeWcgoM    2017-12-19
# TyHvyGVs42U GB       TyHvyGVs42U    2017-12-01
# 6ZfuNTqbHE8 GB       6ZfuNTqbHE8    2017-12-14
# UceaB4D0jpo GB       UceaB4D0jpo    2017-12-06
# rRzxEiBLQCA GB       rRzxEiBLQCA    2017-12-24
# FlsCjmMhFmw GB       FlsCjmMhFmw    2017-12-24
#
#                                                                  title  \
# video_id    Country
# kTlv5_Bs8aw GB       BTS (방탄소년단) 'MIC Drop (Steve Aoki Remix)' Offi...
# 2Vv-BfVoq4g GB             Ed Sheeran - Perfect (Official Music Video)
# 817P8W8-mGE GB       Ed Sheeran - Perfect Duet (with Beyoncé) [Offi...
# l_lblj8Cq0o GB       G-Eazy - No Limit REMIX ft. A$AP Rocky, Cardi ...
# vn9mMeWcgoM GB       Jurassic World: Fallen Kingdom - Official Trai...
# TyHvyGVs42U GB               Luis Fonsi, Demi Lovato - Échame La Culpa
# 6ZfuNTqbHE8 GB       Marvel Studios' Avengers: Infinity War Officia...
# UceaB4D0jpo GB                    Post Malone - rockstar ft. 21 Savage
# rRzxEiBLQCA GB                                  TWICE Heart Shaker M/V
# FlsCjmMhFmw GB       YouTube Rewind: The Shape of 2017 | #YouTubeRe...
#
#                             channel_title  category_id   category_name  \
# video_id    Country
# kTlv5_Bs8aw GB                    ibighit           10           Music
# 2Vv-BfVoq4g GB                 Ed Sheeran           10           Music
# 817P8W8-mGE GB                 Ed Sheeran           10           Music
# l_lblj8Cq0o GB             GEazyMusicVEVO           10           Music
# vn9mMeWcgoM GB         Universal Pictures           24   Entertainment
# TyHvyGVs42U GB              LuisFonsiVEVO           10           Music
# 6ZfuNTqbHE8 GB       Marvel Entertainment           24   Entertainment
# UceaB4D0jpo GB             PostMaloneVEVO           10           Music
# rRzxEiBLQCA GB           jypentertainment           10           Music
# FlsCjmMhFmw GB          YouTube Spotlight           24   Entertainment
#
#                                  publish_time      views    likes  dislikes  \
# video_id    Country
# kTlv5_Bs8aw GB       2017-11-24T09:00:02.000Z   54083634  2960250     57944
# 2Vv-BfVoq4g GB       2017-11-09T11:04:14.000Z  138578860  2584773     49428
# 817P8W8-mGE GB       2017-12-01T00:54:56.000Z   76816483  1221200     39201
# l_lblj8Cq0o GB       2017-12-19T20:00:05.000Z   56253155   805351     49423
# vn9mMeWcgoM GB       2017-12-08T01:44:25.000Z   41612497   566948     28954
# TyHvyGVs42U GB       2017-11-17T05:00:01.000Z  143408235  2686169    137938
# 6ZfuNTqbHE8 GB       2017-11-29T13:26:24.000Z  100672931  2701353     56313
# UceaB4D0jpo GB       2017-11-22T05:00:01.000Z   71173287  1642648     52596
# rRzxEiBLQCA GB       2017-12-11T08:59:59.000Z   55754734  1052809    103994
# FlsCjmMhFmw GB       2017-12-06T17:58:51.000Z  169884583  3312868   1753274
#
#                      comment_count  comments_disabled  ratings_disabled  \
# video_id    Country
# kTlv5_Bs8aw GB              556154              False             False
# 2Vv-BfVoq4g GB              113639              False             False
# 817P8W8-mGE GB               51421              False             False
# l_lblj8Cq0o GB               46178              False             False
# vn9mMeWcgoM GB               68309              False             False
# TyHvyGVs42U GB              144217              False             False
# 6ZfuNTqbHE8 GB              368739              False             False
# UceaB4D0jpo GB              108846              False             False
# rRzxEiBLQCA GB              169779              False             False
# FlsCjmMhFmw GB              845233              False             False
#
#                      video_error_or_removed Country
# video_id    Country
# kTlv5_Bs8aw GB                        False      GB
# 2Vv-BfVoq4g GB                        False      GB
# 817P8W8-mGE GB                        False      GB
# l_lblj8Cq0o GB                        False      GB
# vn9mMeWcgoM GB                        False      GB
# TyHvyGVs42U GB                        False      GB
# 6ZfuNTqbHE8 GB                        False      GB
# UceaB4D0jpo GB                        False      GB
# rRzxEiBLQCA GB                        False      GB
# FlsCjmMhFmw GB                        False      GB

# %% [markdown]
# #### 2.2.3 Countries that Dominate Top 10 Users (Channel Titles)

# %%
eval3 = youtube_df[youtube_df["category_name"].isin(category_namesC)]
eval3.loc[eval3.groupby(["category_name"])["views"].idxmax()]
# Out:
#                         video_id trending_date  \
# video_id    Country
# wzKL-bQKcgA GB       wzKL-bQKcgA    2017-12-30
# FlsCjmMhFmw GB       FlsCjmMhFmw    2017-12-24
# TyHvyGVs42U GB       TyHvyGVs42U    2017-12-01
# sXP6vliZIHI GB       sXP6vliZIHI    2018-01-05
# Ha3WCbl7S7s CA       Ha3WCbl7S7s    2017-12-14
#
#                                                                  title  \
# video_id    Country
# wzKL-bQKcgA GB       Anitta & J Balvin - Downtown (Official Lyric V...
# FlsCjmMhFmw GB       YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# TyHvyGVs42U GB               Luis Fonsi, Demi Lovato - Échame La Culpa
# sXP6vliZIHI GB       Cardi B - Bartier Cardi (feat. 21 Savage) [Off...
# Ha3WCbl7S7s CA       Virat Kohli And Anushka Sharma Marriage Ceremo...
#
#                          channel_title  category_id    category_name  \
# video_id    Country
# wzKL-bQKcgA GB               Lele Pons           23           Comedy
# FlsCjmMhFmw GB       YouTube Spotlight           24    Entertainment
# TyHvyGVs42U GB           LuisFonsiVEVO           10            Music
# sXP6vliZIHI GB                 Cardi B           22   People & Blogs
# Ha3WCbl7S7s CA            Sports Blast           17           Sports
#
#                                  publish_time      views    likes  dislikes  \
# video_id    Country
# wzKL-bQKcgA GB       2017-12-14T18:30:08.000Z   43460605  1253154     38693
# FlsCjmMhFmw GB       2017-12-06T17:58:51.000Z  169884583  3312868   1753274
# TyHvyGVs42U GB       2017-11-17T05:00:01.000Z  143408235  2686169    137938
# sXP6vliZIHI GB       2017-12-22T05:00:02.000Z   19020671   396911     21465
# Ha3WCbl7S7s CA       2017-12-11T18:18:17.000Z   15860214   131887      9601
#
#                      comment_count  comments_disabled  ratings_disabled  \
# video_id    Country
# wzKL-bQKcgA GB               58235              False             False
# FlsCjmMhFmw GB              845233              False             False
# TyHvyGVs42U GB              144217              False             False
# sXP6vliZIHI GB               29562              False             False
# Ha3WCbl7S7s CA                6563              False             False
#
#                      video_error_or_removed Country
# video_id    Country
# wzKL-bQKcgA GB                        False      GB
# FlsCjmMhFmw GB                        False      GB
# TyHvyGVs42U GB                        False      GB
# sXP6vliZIHI GB                        False      GB
# Ha3WCbl7S7s CA                        False      CA

# %% [markdown]
# ## 3.0

# %% [markdown]
# Ideas:
#
# Create visualizations
#
# ask preliminary questions
#
# Go through stats?
#
# Do an a/b test?
#
# do a linear regression of likes vs views?
#
# sentiment analysis?
#
#
# Should I create a dialogue surrounding likes, comments, and dislikes. Thereafter, connect that to Sentiment analysis? Lastly, then try to predict bad or good cases through regression?

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Conclusion
